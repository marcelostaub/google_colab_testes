# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelostaub/google_colab_testes/blob/main/ManipulandoDadosPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import pandas as pd

# %%
import yfinance as yf

# %%
acao = yf.Ticker('BRSR6.SA')
dados = acao.history(period='1y')

# %%
dados
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496  13.776507  13.941496
# 2024-02-27 00:00:00-03:00  13.978159  14.143147  13.941495  14.124815
# 2024-02-28 00:00:00-03:00  14.143148  14.418127  14.106484  14.308135
# 2024-02-29 00:00:00-03:00  14.225643  14.390630  13.978160  14.143148
# 2024-03-01 00:00:00-03:00  13.849834  13.886498  13.382369  13.666514
# ...                              ...        ...        ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.640000  10.300000  10.570000
# 2025-02-19 00:00:00-03:00  10.560000  10.660000  10.470000  10.550000
# 2025-02-20 00:00:00-03:00  10.550000  10.640000  10.480000  10.550000
# 2025-02-21 00:00:00-03:00  10.550000  10.770000  10.490000  10.670000
# 2025-02-24 00:00:00-03:00  10.710000  10.820000  10.660000  10.730000
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = dados.filter(items=['Open', 'Close'])

# %%
df
# Out:
#                                 Open      Close
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496
# 2024-02-27 00:00:00-03:00  13.978159  14.124815
# 2024-02-28 00:00:00-03:00  14.143148  14.308135
# 2024-02-29 00:00:00-03:00  14.225643  14.143148
# 2024-03-01 00:00:00-03:00  13.849834  13.666514
# ...                              ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.570000
# 2025-02-19 00:00:00-03:00  10.560000  10.550000
# 2025-02-20 00:00:00-03:00  10.550000  10.550000
# 2025-02-21 00:00:00-03:00  10.550000  10.670000
# 2025-02-24 00:00:00-03:00  10.710000  10.730000
#
# [252 rows x 2 columns]

# %%
df2 = dados.filter(like='gh', axis=1)

# %%
df2
# Out:
#                                 High
# Date
# 2024-02-26 00:00:00-03:00  13.941496
# 2024-02-27 00:00:00-03:00  14.143147
# 2024-02-28 00:00:00-03:00  14.418127
# 2024-02-29 00:00:00-03:00  14.390630
# 2024-03-01 00:00:00-03:00  13.886498
# ...                              ...
# 2025-02-18 00:00:00-03:00  10.640000
# 2025-02-19 00:00:00-03:00  10.660000
# 2025-02-20 00:00:00-03:00  10.640000
# 2025-02-21 00:00:00-03:00  10.770000
# 2025-02-24 00:00:00-03:00  10.820000
#
# [252 rows x 1 columns]

# %%
df3 = dados[(dados.index > '2025-02-01')]

# %%
df3
# Out:
#                             Open   High    Low  Close   Volume  Dividends  \
# Date
# 2025-02-03 00:00:00-03:00  10.25  10.44  10.20  10.34  1329400        0.0
# 2025-02-04 00:00:00-03:00  10.34  10.43  10.23  10.36  1069300        0.0
# 2025-02-05 00:00:00-03:00  10.40  10.49  10.30  10.39  1463000        0.0
# 2025-02-06 00:00:00-03:00  10.35  10.50  10.34  10.41   982200        0.0
# 2025-02-07 00:00:00-03:00  10.37  10.47  10.31  10.42   868000        0.0
# 2025-02-10 00:00:00-03:00  10.41  10.63  10.36  10.62   928700        0.0
# 2025-02-11 00:00:00-03:00  10.63  10.73  10.56  10.63   849200        0.0
# 2025-02-12 00:00:00-03:00  10.60  10.66  10.16  10.16  2057800        0.0
# 2025-02-13 00:00:00-03:00  10.08  10.32  10.00  10.07  1640700        0.0
# 2025-02-14 00:00:00-03:00  10.11  10.33  10.08  10.30  2531500        0.0
# 2025-02-17 00:00:00-03:00  10.17  10.41  10.17  10.37  1299400        0.0
# 2025-02-18 00:00:00-03:00  10.37  10.64  10.30  10.57  1141300        0.0
# ...

# %%
df = dados.Close

# %%
df
# Out:
# Date
# 2024-02-26 00:00:00-03:00    13.941496
# 2024-02-27 00:00:00-03:00    14.124815
# 2024-02-28 00:00:00-03:00    14.308135
# 2024-02-29 00:00:00-03:00    14.143148
# 2024-03-01 00:00:00-03:00    13.666514
#                                ...
# 2025-02-18 00:00:00-03:00    10.570000
# 2025-02-19 00:00:00-03:00    10.550000
# 2025-02-20 00:00:00-03:00    10.550000
# 2025-02-21 00:00:00-03:00    10.670000
# 2025-02-24 00:00:00-03:00    10.730000
# Name: Close, Length: 252, dtype: float64

# %%
df = dados['Close']

# %%
df
# Out:
# Date
# 2024-02-26 00:00:00-03:00    13.941496
# 2024-02-27 00:00:00-03:00    14.124815
# 2024-02-28 00:00:00-03:00    14.308135
# 2024-02-29 00:00:00-03:00    14.143148
# 2024-03-01 00:00:00-03:00    13.666514
#                                ...
# 2025-02-18 00:00:00-03:00    10.570000
# 2025-02-19 00:00:00-03:00    10.550000
# 2025-02-20 00:00:00-03:00    10.550000
# 2025-02-21 00:00:00-03:00    10.670000
# 2025-02-24 00:00:00-03:00    10.730000
# Name: Close, Length: 252, dtype: float64

# %%
df = dados[['Open', 'Close']]

# %%
df
# Out:
#                                 Open      Close
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496
# 2024-02-27 00:00:00-03:00  13.978159  14.124815
# 2024-02-28 00:00:00-03:00  14.143148  14.308135
# 2024-02-29 00:00:00-03:00  14.225643  14.143148
# 2024-03-01 00:00:00-03:00  13.849834  13.666514
# ...                              ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.570000
# 2025-02-19 00:00:00-03:00  10.560000  10.550000
# 2025-02-20 00:00:00-03:00  10.550000  10.550000
# 2025-02-21 00:00:00-03:00  10.550000  10.670000
# 2025-02-24 00:00:00-03:00  10.710000  10.730000
#
# [252 rows x 2 columns]

# %%
df = dados[['Open', 'High', 'Close']]

# %%
df
# Out:
#                                 Open       High      Close
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496  13.941496
# 2024-02-27 00:00:00-03:00  13.978159  14.143147  14.124815
# 2024-02-28 00:00:00-03:00  14.143148  14.418127  14.308135
# 2024-02-29 00:00:00-03:00  14.225643  14.390630  14.143148
# 2024-03-01 00:00:00-03:00  13.849834  13.886498  13.666514
# ...                              ...        ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.640000  10.570000
# 2025-02-19 00:00:00-03:00  10.560000  10.660000  10.550000
# 2025-02-20 00:00:00-03:00  10.550000  10.640000  10.550000
# 2025-02-21 00:00:00-03:00  10.550000  10.770000  10.670000
# 2025-02-24 00:00:00-03:00  10.710000  10.820000  10.730000
#
# [252 rows x 3 columns]

# %%
df = dados.index

# %%
df
# Out:
# DatetimeIndex(['2024-02-26 00:00:00-03:00', '2024-02-27 00:00:00-03:00',
#                '2024-02-28 00:00:00-03:00', '2024-02-29 00:00:00-03:00',
#                '2024-03-01 00:00:00-03:00', '2024-03-04 00:00:00-03:00',
#                '2024-03-05 00:00:00-03:00', '2024-03-06 00:00:00-03:00',
#                '2024-03-07 00:00:00-03:00', '2024-03-08 00:00:00-03:00',
#                ...
#                '2025-02-11 00:00:00-03:00', '2025-02-12 00:00:00-03:00',
#                '2025-02-13 00:00:00-03:00', '2025-02-14 00:00:00-03:00',
#                '2025-02-17 00:00:00-03:00', '2025-02-18 00:00:00-03:00',
#                '2025-02-19 00:00:00-03:00', '2025-02-20 00:00:00-03:00',
#                '2025-02-21 00:00:00-03:00', '2025-02-24 00:00:00-03:00'],
#               dtype='datetime64[ns, America/Sao_Paulo]', name='Date', length=252, freq=None)

# %%
df = dados.drop(['2025-02-24', '2025-02-21'], axis=0)

# %%
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496  13.776507  13.941496
# 2024-02-27 00:00:00-03:00  13.978159  14.143147  13.941495  14.124815
# 2024-02-28 00:00:00-03:00  14.143148  14.418127  14.106484  14.308135
# 2024-02-29 00:00:00-03:00  14.225643  14.390630  13.978160  14.143148
# 2024-03-01 00:00:00-03:00  13.849834  13.886498  13.382369  13.666514
# ...                              ...        ...        ...        ...
# 2025-02-14 00:00:00-03:00  10.110000  10.330000  10.080000  10.300000
# 2025-02-17 00:00:00-03:00  10.170000  10.410000  10.170000  10.370000
# 2025-02-18 00:00:00-03:00  10.370000  10.640000  10.300000  10.570000
# 2025-02-19 00:00:00-03:00  10.560000  10.660000  10.470000  10.550000
# 2025-02-20 00:00:00-03:00  10.550000  10.640000  10.480000  10.550000
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
df = dados.drop(['Low', 'High'], axis=1)

# %%
df
# Out:
#                                 Open      Close   Volume  Dividends  \
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496   553100        0.0
# 2024-02-27 00:00:00-03:00  13.978159  14.124815   764300        0.0
# 2024-02-28 00:00:00-03:00  14.143148  14.308135  1334600        0.0
# 2024-02-29 00:00:00-03:00  14.225643  14.143148  1434900        0.0
# 2024-03-01 00:00:00-03:00  13.849834  13.666514  3777900        0.0
# ...                              ...        ...      ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.570000  1141300        0.0
# 2025-02-19 00:00:00-03:00  10.560000  10.550000  2771700        0.0
# 2025-02-20 00:00:00-03:00  10.550000  10.550000  2472300        0.0
# 2025-02-21 00:00:00-03:00  10.550000  10.670000  2312000        0.0
# 2025-02-24 00:00:00-03:00  10.710000  10.730000  1900700        0.0
#
#                            Stock Splits
# Date
# 2024-02-26 00:00:00-03:00           0.0
# 2024-02-27 00:00:00-03:00           0.0
# ...

# %%
df['new_dividends'] = dados['Dividends'].map({0:2.00})

# %%
df
# Out:
#                                 Open      Close   Volume  Dividends  \
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496   553100        0.0
# 2024-02-27 00:00:00-03:00  13.978159  14.124815   764300        0.0
# 2024-02-28 00:00:00-03:00  14.143148  14.308135  1334600        0.0
# 2024-02-29 00:00:00-03:00  14.225643  14.143148  1434900        0.0
# 2024-03-01 00:00:00-03:00  13.849834  13.666514  3777900        0.0
# ...                              ...        ...      ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.570000  1141300        0.0
# 2025-02-19 00:00:00-03:00  10.560000  10.550000  2771700        0.0
# 2025-02-20 00:00:00-03:00  10.550000  10.550000  2472300        0.0
# 2025-02-21 00:00:00-03:00  10.550000  10.670000  2312000        0.0
# 2025-02-24 00:00:00-03:00  10.710000  10.730000  1900700        0.0
#
#                            Stock Splits  new_dividends
# Date
# 2024-02-26 00:00:00-03:00           0.0            2.0
# ...

# %%
df['new_dividends'] = dados['Dividends'].map({0:2.00}).where(dados.index == '2024-02-26')

# %%
df
# Out:
#                                 Open      Close   Volume  Dividends  \
# Date
# 2024-02-26 00:00:00-03:00  13.831504  13.941496   553100        0.0
# 2024-02-27 00:00:00-03:00  13.978159  14.124815   764300        0.0
# 2024-02-28 00:00:00-03:00  14.143148  14.308135  1334600        0.0
# 2024-02-29 00:00:00-03:00  14.225643  14.143148  1434900        0.0
# 2024-03-01 00:00:00-03:00  13.849834  13.666514  3777900        0.0
# ...                              ...        ...      ...        ...
# 2025-02-18 00:00:00-03:00  10.370000  10.570000  1141300        0.0
# 2025-02-19 00:00:00-03:00  10.560000  10.550000  2771700        0.0
# 2025-02-20 00:00:00-03:00  10.550000  10.550000  2472300        0.0
# 2025-02-21 00:00:00-03:00  10.550000  10.670000  2312000        0.0
# 2025-02-24 00:00:00-03:00  10.710000  10.730000  1900700        0.0
#
#                            Stock Splits  new_dividends
# Date
# 2024-02-26 00:00:00-03:00           0.0            2.0
# ...

# %%
bova = pd.read_csv('/content/all_bovespa.csv')

# %%
bova
# Out:
#       data_pregao sigla_acao     nome_acao  preco_abertura  preco_maximo  \
# 0      2024-01-02      AALR3        ALLIAR           10.20         10.36
# 1      2024-01-02      ABCB4    ABC BRASIL           23.98         23.98
# 2      2024-01-02      ABEV3     AMBEV S/A           13.72         13.73
# 3      2024-01-02      BBDC3      BRADESCO           15.26         15.26
# 4      2024-01-02      ALPA3    ALPARGATAS           10.11         10.30
# ...           ...        ...           ...             ...           ...
# 23314  2024-04-05      PETR3     PETROBRAS           39.02         39.50
# 23315  2024-04-05      PETR4     PETROBRAS           37.90         38.57
# 23316  2024-04-05      JHSF3     JHSF PART            4.75          4.77
# 23317  2024-04-05      JSLG3           JSL           12.62         13.25
# 23318  2024-04-05      KEPL3  KEPLER WEBER           10.35         10.47
#
#        preco_minimo  preco_fechamento  qtd_negocios  volume_negocios
# ...

# %%
df_banri = bova[bova['sigla_acao']=='BRSR6']

# %%
df_banri
# Out:
#       data_pregao sigla_acao nome_acao  preco_abertura  preco_maximo  \
# 295    2024-01-02      BRSR6  BANRISUL           13.30         13.34
# 570    2024-01-03      BRSR6  BANRISUL           12.77         13.03
# 934    2024-01-04      BRSR6  BANRISUL           12.94         12.97
# 1381   2024-01-05      BRSR6  BANRISUL           12.85         13.29
# 1628   2024-01-08      BRSR6  BANRISUL           13.24         13.47
# ...           ...        ...       ...             ...           ...
# 21587  2024-04-01      BRSR6  BANRISUL           13.37         13.48
# 22023  2024-04-02      BRSR6  BANRISUL           13.09         13.25
# 22566  2024-04-03      BRSR6  BANRISUL           13.22         13.32
# 22859  2024-04-04      BRSR6  BANRISUL           13.27         13.46
# 23007  2024-04-05      BRSR6  BANRISUL           13.35         13.53
#
#        preco_minimo  preco_fechamento  qtd_negocios  volume_negocios
# 295           12.78             12.83     1826800.0     2.373023e+09
# ...

# %%
df_banri['nome_acao'] = df_banri['nome_acao'].replace('BANRISUL', 'BANRISUL.SA')
# Out:
# <ipython-input-38-8fad0776d07a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_banri['nome_acao'] = df_banri['nome_acao'].replace('BANRISUL', 'BANRISUL.SA')

# %%
df_banri
# Out:
#       data_pregao sigla_acao    nome_acao  preco_abertura  preco_maximo  \
# 295    2024-01-02      BRSR6  BANRISUL.SA           13.30         13.34
# 570    2024-01-03      BRSR6  BANRISUL.SA           12.77         13.03
# 934    2024-01-04      BRSR6  BANRISUL.SA           12.94         12.97
# 1381   2024-01-05      BRSR6  BANRISUL.SA           12.85         13.29
# 1628   2024-01-08      BRSR6  BANRISUL.SA           13.24         13.47
# ...           ...        ...          ...             ...           ...
# 21587  2024-04-01      BRSR6  BANRISUL.SA           13.37         13.48
# 22023  2024-04-02      BRSR6  BANRISUL.SA           13.09         13.25
# 22566  2024-04-03      BRSR6  BANRISUL.SA           13.22         13.32
# 22859  2024-04-04      BRSR6  BANRISUL.SA           13.27         13.46
# 23007  2024-04-05      BRSR6  BANRISUL.SA           13.35         13.53
#
#        preco_minimo  preco_fechamento  qtd_negocios  volume_negocios
# ...

# %%
df_missing = pd.DataFrame({'A': [0,1,2,None,4],
			'B': [5,6,None,8,9],
			'C': ['a','b','a','a',None]})

# %%
df_missing
# Out:
#      A    B     C
# 0  0.0  5.0     a
# 1  1.0  6.0     b
# 2  2.0  NaN     a
# 3  NaN  8.0     a
# 4  4.0  9.0  None

# %%
df_missing.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3   True  False  False
# 4  False  False   True

# %%
df_missing.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# dtype: int64

# %%
media = df_missing['A'].mean()

# %%
media
# Out:
# 1.75

# %%
df_missing = df_missing['A'].fillna(media)

# %%
df_missing
# Out:
# 0    0.00
# 1    1.00
# 2    2.00
# 3    1.75
# 4    4.00
# Name: A, dtype: float64

# %%
media
# Out:
# 1.75

# %%
df_missing = pd.DataFrame({'A': [0,1,2,None,4],
			'B': [5,6,None,8,9],
			'C': ['a','b','a','a',None]})

# %%
df_missing
# Out:
#      A    B     C
# 0  0.0  5.0     a
# 1  1.0  6.0     b
# 2  2.0  NaN     a
# 3  NaN  8.0     a
# 4  4.0  9.0  None

# %%
moda = df_missing['B'].mode()

# %%
moda
# Out:
# 0    5.0
# 1    6.0
# 2    8.0
# 3    9.0
# Name: B, dtype: float64

# %%
moda.count()
# Out:
# 4

# %%
df_missing2 = pd.DataFrame({'A': [0,1,2,None,4],
			'B': [5,6,None,8,9],
			'C': [2,2,2,None,4]})

# %%
df_missing2
# Out:
#      A    B    C
# 0  0.0  5.0  2.0
# 1  1.0  6.0  2.0
# 2  2.0  NaN  2.0
# 3  NaN  8.0  NaN
# 4  4.0  9.0  4.0

# %%
moda = df_missing2['C'].mode()

# %%
moda
# Out:
# 0    2.0
# Name: C, dtype: float64

# %%
moda[0]
# Out:
# 2.0

# %%
mediana = df_missing2['B'].median()

# %%
mediana
# Out:
# 7.0

# %%
media = df_missing['A'].mean()

# %%
media
# Out:
# 1.75

# %%
df_missing2 = df_missing2.fillna(value={'A':media, 'B':mediana, 'C':moda})

# %%
df_missing2
# Out:
#       A    B    C
# 0  0.00  5.0  2.0
# 1  1.00  6.0  2.0
# 2  2.00  7.0  2.0
# 3  1.75  8.0  2.0
# 4  4.00  9.0  4.0

# %%
df_missing2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4fb7ad86e71b> in <cell line: 0>()
# ----> 1 df_missing2
#
# NameError: name 'df_missing2' is not defined
